# %%
# dictionary to keep track of relevant data in the vehicles dataset
vehicles_lookup = {
    0: {
        'Name': 'Vehicle_Reference',
        'Type': 'Categorical',
        'Map': None
    },
    1: {
        'Name': 'Vehicle_Type',
        'Type': 'Categorical',
        'Map': variable_lookup[22]['label']
    },
    2: {
        'Name': 'Towing_and_Articulation',
        'Type': 'Categorical',
        'Map': variable_lookup[23]['label']
    },
    3: {
        'Name': 'Vehicle_Manoeuvre',
        'Type': 'Categorical',
        'Map': variable_lookup[24]['label']
    },
    4: {
        'Name': 'Vehicle_Location-Restricted_Lane',
        'Type': 'Categorical',
        'Map': variable_lookup[25]['label']
    },
    5: {
        'Name': 'Junction_Location',
        'Type': 'Categorical',
        'Map': variable_lookup[26]['label']
    },
    6: {
        'Name': 'Skidding_and_Overturning',
        'Type': 'Categorical',
        'Map': variable_lookup[27]['label']
    },
    7: {
        'Name': 'Hit_Object_in_Carriageway',
        'Type': 'Categorical',
        'Map': variable_lookup[28]['label']
    },
    8: {
        'Name': 'Vehicle_Leaving_Carriageway',
        'Type': 'Categorical',
        'Map': variable_lookup[29]['label']
    }, 
    9: {
        'Name': 'Hit_Object_off_Carriageway',
        'Type': 'Categorical',
        'Map': variable_lookup[30]['label']
    },
    10: {
        'Name': '1st_Point_of_Impact',
        'Type': 'Categorical',
        'Map': variable_lookup[31]['label']
    },
    11: {
        'Name': 'Was_Vehicle_Left_Hand_Drive?',
        'Type': 'Categorical',
        'Map': variable_lookup[32]['label']
    },
    12: {
        'Name': 'Journey_Purpose_of_Driver',
        'Type': 'Categorical',
        'Map': variable_lookup[33]['label']
    },
    13: {
        'Name': 'Sex_of_Driver',
        'Type': 'Categorical',
        'Map': variable_lookup[34]['label']
    },
    14: {
        'Name': 'Age_of_Driver',
        'Type': 'Numerical',
        'Map': None
    },
    15: {
        'Name': 'Age_Band_of_Driver',
        'Type': 'Categorical',
        'Map': variable_lookup[35]['label']
    },
    16: {
        'Name': 'Engine_Capacity_(CC)',
        'Type': 'Numerical',
        'Map': None
    },
    17: {
        'Name': 'Propulsion_Code',
        'Type': 'Categorical',
        'Map': variable_lookup[36]['label']
    },
    18: {
        'Name': 'Age_of_Vehicle',
        'Type': 'Numerical',
        'Map': None
    }, 
    19: {
        'Name': 'Driver_IMD_Decile',
        'Type': 'Numerical',
        'Map': None
    },
    20: {
        'Name': 'Driver_Home_Area_Type',
        'Type': 'Numerical',
        'Map': None
    },
    21: {
        'Name': 'Vehicle_IMD_Decile',
        'Type': 'Numerical',
        'Map': None
    },
}

# %%
# dictionary to keep track of relevant data in the accidents dataset
accidents_lookup = {
    0: {
        "Name": "Accident_Index", 
        "Type": "Categorical", 
        "Map": None
    },
    1: {
        "Name": "Location_Easting_OSGR",
        "Type": "Numerical", 
        "Map": None
    },
    2: {
        "Name": "Location_Northing_OSGR",
        "Type": "Numerical", 
        "Map": None
    }, 
    3: {
        "Name": "Longitude", 
        "Type": "Numerical",
        "Map": None
    },
    4: {
        "Name": "Latitude",
        "Type": "Numerical",
        "Map": None
    },
    5: {
        "Name": "Police_Force",
        "Type": "Categorical",
        "Map": variable_lookup[2]['label']
    },
    6: {
        "Name": "Accident_Severity",
        "Type": "Categorical",
        "Map": variable_lookup[3]['label']
    }, 
    7: {
        "Name": "Number_of_Vehicles",
        "Type": "Categorical",
        "Map": None
    },
    8: {
        "Name": "Number_of_Casualties",
        "Type": "Categorical",
        "Map": None
    },
    9: {
        "Name": "Date",
        "Type": "Date",
        "Map": None
    },
    10: {
        "Name": "Day_of_Week",
        "Type": "Categorical",
        "Map": variable_lookup[4]['label']
    },
    11: {
        "Name": "Time",
        "Type": "Categorical",
        "Map": {0: "0-1", 1: "1-2", 2: "2-3", 3: "3-4", 4: "4-5", 5: "5-6", 6: "6-7", 7: "7-8", 8: "8-9", 9: "9-10", 
                10: "10-11", 11: "11-12", 12: "12-13", 13: "13-14", 14: "14-15", 15: "15-16", 16: "16-17", 17: "17-18", 
                18: "18-19", 19: "19-20", 20: "20-21", 21: "21-22", 22: "22-23", 23: "23-0", -1: "Missing Value"}
    },
    12: {
        "Name": "Local_Authority_(District)",
        "Type": "Categorical",
        "Map": {204: "Leeds"}
    },
    13: {
        "Name": "Local_Authority_(Highway)",
        "Type": "Categorical",
        "Map": {"E08000035": "Leeds"}
    },
    14: {
        "Name": "1st_Road_Class",
        "Type": "Categorical",
        "Map": variable_lookup[7]['label']
    },
    15: {
        "Name": "1st_Road_Number",
        "Type": "Numerical",
        "Map": None
    },
    16: {
        "Name": "Road_Type",
        "Type": "Categorical",
        "Map": variable_lookup[8]['label']
    },
    17: {
        "Name": "Speed_limit",
        "Type": "Categorical",
        "Map": variable_lookup[9]['label']
    },
    18: {
        "Name": "Junction_Detail",
        "Type": "Categorical",
        "Map": variable_lookup[10]['label']
    },
    19: {
        "Name": "Junction_Control",
        "Type": "Categorical",
        "Map": variable_lookup[11]['label']
    },
    20: {
        "Name": "2nd_Road_Class",
        "Type": "Categorical",
        "Map": variable_lookup[12]['label']
    },
    21: {
        "Name": "2nd_Road_Number",
        "Type": "Numerical",
        "Map": None
    },
    22: {
        "Name": "Pedestrian_Crossing-Human_Control",
        "Type": "Categorical",
        "Map": variable_lookup[13]['label']
    },
    23: {
        "Name": "Pedestrian_Crossing-Physical_Facilities",
        "Type": "Categorical",
        "Map": variable_lookup[14]['label']
    },
    24: {
        "Name": "Light_Conditions",
        "Type": "Categorical",
        "Map": variable_lookup[15]['label']
    },
    25: {
        "Name": "Weather_Conditions",
        "Type": "Categorical",
        "Map": variable_lookup[16]['label']
    },
    26: {
        "Name": "Road_Surface_Conditions",
        "Type": "Categorical",
        "Map": variable_lookup[17]['label']
    },
    27: {
        "Name": "Road_Surface_Conditions",
        "Type": "Categorical",
        "Map": variable_lookup[18]['label']
    },
    28: {
        "Name": "Carriageway_Hazards",
        "Type": "Categorical",
        "Map": variable_lookup[19]['label']
    },
    29: {
        "Name": "Urban_or_Rural_Area",
        "Type": "Categorical",
        "Map": variable_lookup[20]['label']
    },
    30: {
        "Name": "Did_Police_Officer_Attend_Scene_of_Accident",
        "Type": "Categorical",
        "Map": variable_lookup[21]['label']
    },
    31: {
        "Name": "LSOA_of_Accident_Location",
        "Type": "Numerical",
        "Map": None
    }
}
